# %%
from PIL import Image
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

img = Image.open('psyduck.png')
img = img.convert('L')
fig, ax = plt.subplots()
ax.contour(img, origin='image', levels=[100])
plt.axis('off')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-795d3f7b8d65> in <module>
#       6 plt.axis('off')
#       7 plt.show()
# ----> 8 plt = plt.convert('L')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'convert'
