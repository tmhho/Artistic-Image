# %%
import time
# %run -i 'poisson.py'
N = 1001
pi = importIMG('../images/pokeball.png', N, show = False)

# %%
start = time.time()
p = PoissonDisc_dwork(0.001,0.02,10,pi)
end = time.time()
print(end - start)
plot_points(p,5)
print(len(p))
# Out:
# 2.0917727947235107
# 6204

# %%
start = time.time()
p = PoissonDisc_tulleken(0.001,0.01,30,pi)
end = time.time()
print(end - start)
plot_points(p,5)
print(len(p))
# Out:
# 0.9151420593261719
# 995
